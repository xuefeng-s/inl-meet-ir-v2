# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data = pd.read_excel('/content/gdrive/MyDrive/Praxisprojekt/Trainingdata.xlsx', sheet_name = 'sentences')
print (data)
data.head()
# Out:
#                                                Sentence  ... SUBJpolit
# 0     miley and liam fighting false rumors swirl tha...  ...         1
# 1           are miley cyrus and liam hemsworth fighting  ...         1
# 2     a new report claims that cyrus and hemsworth h...  ...         1
# 3     according to the report cyrus 24 and hemsworth...  ...         1
# 4     but there has reportedly been tension between ...  ...         1
# ...                                                 ...  ...       ...
# 3297  host joyann reid brought up how rep duncan hun...  ...         5
# 3298  not honorable military veterans because an hon...  ...         3
# 3299                     that line has now been crossed  ...         1
# 3300                                   watch more above  ...         1
# 3301  show us how its done excia interrogator blasts...  ...         5
#
# [3302 rows x 12 columns]
#                                             Sentence  ... SUBJpolit
# ...

# %%
import pandas as pd
data = pd.read_excel('/content/gdrive/MyDrive/Praxisprojekt/Trainingdata.xlsx', sheet_name = 'sentences')
alllength = []
mystuff = data['Sentence'].tolist()
for s in mystuff:
  if type(s) is str:
    alllength.append(len(s))
pd.value_counts(alllength).plot.bar()

# %%
data.drop(['SUBJindl', 'SUBJsrce', 'SUBJrhet', 'SUBJster', 'SUBJspee', 'SUBJinspe', 'SUBJprop', 'SUBJpolit'], axis=1).head()
# Out:
#                                             Sentence  ... SUBJopin
# 0  miley and liam fighting false rumors swirl tha...  ...        1
# 1        are miley cyrus and liam hemsworth fighting  ...        1
# 2  a new report claims that cyrus and hemsworth h...  ...        1
# 3  according to the report cyrus 24 and hemsworth...  ...        1
# 4  but there has reportedly been tension between ...  ...        1
#
# [5 rows x 4 columns]

# %%
pd.value_counts(data['SUBJlang']).plot.bar()
#plt.xlabel="Sentiment-Wert"
plt.title("Sentiment-Werte")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1151495cb8cb> in <module>()
#       1 pd.value_counts(data['SUBJlang']).plot.bar()
#       2 #plt.xlabel="Sentiment-Wert"
# ----> 3 plt.title("Sentiment-Werte")
#
# NameError: name 'plt' is not defined

# %%
from sklearn.feature_selection import chi2
cols2skip = [0,1]  
cols = [i for i in range(10) if i not in cols2skip]
data_without_sentences = pd.read_excel('/content/gdrive/MyDrive/Praxisprojekt/Trainingdata.xlsx', usecols=cols)
X = data.drop('SUBJopin', axis=1)
y = data['SUBJopin']

# %%
chi_scores = chi2(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-46614937482e> in <module>()
# ----> 1 chi_scores = chi2(X,y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_univariate_selection.py in chi2(X, y)
#     212     # XXX: we might want to do some of the following in logspace instead for
#     213     # numerical stability.
# --> 214     X = check_array(X, accept_sparse='csr')
#     215     if np.any((X.data if issparse(X) else X) < 0):
#     216         raise ValueError("Input X must be non-negative.")
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
# ...
